# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_openai import ChatOpenAI
load_dotenv()
import os

# %%
llm=init_chat_model(
    model="google/gemma-3-27b-it:free",
    model_provider="openai",
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
    temperature=0.2,
)

# %%
messages={
    'role':'user',
    'content': [
        {'type':'text','text':'Describe the content of the image'},
        {'type':'image','url':f'https://variety.com/wp-content/uploads/2018/08/one-piece-cr.jpg?w=1000&h=667&crop=1'}
    ]
}

# %%
response = llm.invoke([messages])
print(response.content)
# Out:
# Here's a description of the image:
#
# **Content:**
#
# The image features Monkey D. Luffy, the main character from the popular anime and manga series *One Piece*. He is depicted in a classic anime style with large, expressive eyes and a somewhat distressed expression.
#
# **Details:**
#
# *   **Character:** Luffy is shown from the chest up. He has black spiky hair, a straw hat (his signature item), and a scar under his left eye.
# *   **Expression:** His eyes are wide and slightly downturned, giving him a worried or sad look. His mouth is also slightly downturned.
# *   **Clothing:** He's wearing his usual outfit: a red vest and a simple, open-fronted shirt.
# *   **Background:** The background is a bright blue sky with some fluffy white clouds.
# *   **Object:** A long, brown wooden pole is visible on the left side of the image, partially obscuring Luffy. It appears to be a fishing rod or similar object.
#
# **Overall Impression:**
#
# The image captures a moment of vulnerability or concern for Luffy, contrasting with his typically cheerful and energetic personality. It's a still from the anime series, likely depicting a scene where he's facing a challenge or experiencing a moment of sadness.
